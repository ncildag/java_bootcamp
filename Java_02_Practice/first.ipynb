# %%
from fpdf import FPDF

headers = ["Türkçe", "Emir", "Geçmiş", "Şimdiki Zaman", "Gelecek Zaman"]
verbs = [
    ["gitmek", "اِذْهَبْ", "ذَهَبَ", "يَذْهَبُ", "سَيَذْهَبُ"],
    ["gelmek", "تَعَالَ", "جَاءَ", "يَجِيءُ", "سَيَجِيءُ"],
    ["yemek", "كُلْ", "أَكَلَ", "يَأْكُلُ", "سَيَأْكُلُ"],
    ["içmek", "اِشْرَبْ", "شَرِبَ", "يَشْرَبُ", "سَيَشْرَبُ"],
    ["uyumak", "نَمْ", "نَامَ", "يَنَامُ", "سَيَنَامُ"],
    ["yazmak", "اُكْتُبْ", "كَتَبَ", "يَكْتُبُ", "سَيَكْتُبُ"],
    ["okumak", "اِقْرَأْ", "قَرَأَ", "يَقْرَأُ", "سَيَقْرَأُ"],
    ["konuşmak", "تَكَلَّمْ", "تَكَلَّمَ", "يَتَكَلَّمُ", "سَيَتَكَلَّمُ"],
    ["sevmek", "أَحِبَّ", "أَحَبَّ", "يُحِبُّ", "سَيُحِبُّ"],
    ["nefret etmek", "اِكْرَهْ", "كَرِهَ", "يَكْرَهُ", "سَيَكْرَهُ"],
    ["oturmak", "اِجْلِسْ", "جَلَسَ", "يَجْلِسُ", "سَيَجْلِسُ"],
    ["kalkmak", "قُمْ", "قَامَ", "يَقُومُ", "سَيَقُومُ"],
    ["çalışmak", "اِعْمَلْ", "عَمِلَ", "يَعْمَلُ", "سَيَعْمَلُ"],
    ["beklemek", "اِنْتَظِرْ", "اِنْتَظَرَ", "يَنْتَظِرُ", "سَيَنْتَظِرُ"],
    ["yürümek", "اِمْشِ", "مَشَى", "يَمْشِي", "سَيَمْشِي"],
    ["görmek", "اُنْظُرْ", "رَأَى", "يَرَى", "سَيَرَى"],
    ["duymak", "اِسْمَعْ", "سَمِعَ", "يَسْمَعُ", "سَيَسْمَعُ"],
    ["anlamak", "اِفْهَمْ", "فَهِمَ", "يَفْهَمُ", "سَيَفْهَمُ"],
    ["bilmek", "اِعْلَمْ", "عَلِمَ", "يَعْلَمُ", "سَيَعْلَمُ"],
    ["istemek", "أُرِدْ", "أَرَادَ", "يُرِيدُ", "سَيُرِيدُ"],
]

pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", size=10)
pdf.set_auto_page_break(auto=True, margin=15)

pdf.set_font("Arial", 'B', 14)
pdf.cell(200, 10, txt="Arapça Fiil Çekim Tablosu (Türkçe - Arapça)", ln=True, align='C')
pdf.ln(5)
pdf.set_font("Arial", size=10)

for header in headers:
    pdf.cell(38, 10, header, border=1, align='C')
pdf.ln()

for row in verbs:
    for item in row:
        pdf.cell(38, 10, item, border=1)
    pdf.ln()

pdf.output("Arapca_Fiil_Cekimleri.pdf")
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[1], line 46
#      43         pdf.cell(38, 10, item, border=1)
#      44     pdf.ln()
# ---> 46 pdf.output("Arapca_Fiil_Cekimleri.pdf")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/fpdf/fpdf.py:1065, in FPDF.output(self, name, dest)
#    1063 #Finish document if necessary
#    1064 if(self.state<3):
# -> 1065     self.close()
#    1066 dest=dest.upper()
#    1067 if(dest==''):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/fpdf/fpdf.py:246, in FPDF.close(self)
#     244 self._endpage()
#     245 #close document
# --> 246 self._enddoc()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/fpdf/fpdf.py:1636, in FPDF._enddoc(self)
#    1634 def _enddoc(self):
#    1635     self._putheader()
# ...

# %%
pip install FPDF
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for FPDF: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=50e1e30e37ef9d11d3211e9d4ee668a6fda4cf7b35d787b8282bdff1e5634095
#   Stored in directory: /Users/nurullahcildag/Library/Caches/pip/wheels/6e/62/11/dc73d78e40a218ad52e7451f30166e94491be013a7850b5d75
# Successfully built FPDF
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 25.2
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fpdf2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.7/251.7 kB 10.5 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 25.2
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pdf.add_font("DejaVu", "", "/path/to/fonts/DejaVuSans.ttf", uni=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pdf.add_font("DejaVu", "", "/path/to/fonts/DejaVuSans.ttf", uni=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/fpdf/fpdf.py:469, in add_font(self, family, style, fname, uni)
#     464 @property
#     465 def is_ttf_font(self) -> bool:
#     466     return self.current_font and self.current_font.type == "TTF"
#     468 @property
# --> 469 def page_mode(self) -> PageMode:
#     470     return self._page_mode
#     472 @page_mode.setter
#     473 def page_mode(self, page_mode):
#
# RuntimeError: TTF Font file not found: /path/to/fonts/DejaVuSans.ttf
